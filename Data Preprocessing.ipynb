# %%
import numpy as np
import cv2 as cv
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = open("./MTFL/training.txt","r")
l = file.readlines()

# %%
data = []
image = []
for i in l:
    if(len(i.split())==15):
        #image.append(i.split()[0])
        i = i.replace("\\",'/')
        data.append(i.split())

# %%
df = pd.DataFrame(data,columns=['image','x1','x2','x3','x4','x5','y1','y2','y3','y4','y5','gender','smile','glass','pose'])

# %%
df['gender']=df['gender'].astype(np.float64)
df['x1']=df['x1'].astype(np.float64)
df['x2']=df['x2'].astype(np.float64)
df['x3']=df['x3'].astype(np.float64)
df['x4']=df['x4'].astype(np.float64)
df['x5']=df['x5'].astype(np.float64)
df['y1']=df['y1'].astype(np.float64)
df['y2']=df['y2'].astype(np.float64)
df['y3']=df['y3'].astype(np.float64)
df['y4']=df['y4'].astype(np.float64)
df['y5']=df['y5'].astype(np.float64)
df['smile']=df['smile'].astype(np.float64)
df['pose']=df['pose'].astype(np.float64)
df['glass'] =df['glass'].astype(np.float64)

# %%
image_array=[]
def resizeImage(location):
    img = cv.imread('./MTFL/'+location,0)
    shape=img.shape
    #print(shape)
    img = cv.resize(img,(150,150),interpolation = cv.INTER_AREA)
    landmarksX = ['x1','x2','x3','x4','x5']
    landmarksY = ['y1','y2','y3','y4','y5']
    for landmark in landmarksX:
        df[landmark][df['image']==location] = df[landmark][df['image']==location]*(150/shape[1])
    for landmark in landmarksY:
        df[landmark][df['image']==location] = df[landmark][df['image']==location]*(150/shape[0])
    image_array.append(img)

# %%
count=0
for i in df['image']:
    count+=1
    resizeImage(i)
    if count%100==0:
        print(count)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# ...

# %%
im_array = np.array(image_array)
im_array.shape
# Out:
# (10000, 150, 150)

# %%
np.save("image_details",im_array)

# %%
im=np.load("image_details.npy")

# %%
df.to_csv("preprocessed.csv",index=False)

# %%
df = pd.read_csv("preprocessed.csv")

# %%
df['map_to_img']=[i for i in range(10000)]

# %%
df.to_csv("preprocessed.csv",index=False)

# %%
df
# Out:
#                                          image       x1        x2       x3  \
# 0              lfw_5590/Aaron_Eckhart_0001.jpg  64.3500   88.6500  75.7500
# 1                lfw_5590/Aaron_Guiel_0001.jpg  60.7500   88.0500  75.1500
# 2              lfw_5590/Aaron_Peirsol_0001.jpg  64.6500   88.6500  78.1500
# 3                 lfw_5590/Aaron_Pena_0001.jpg  61.6500   87.7500  75.7500
# 4               lfw_5590/Aaron_Sorkin_0001.jpg  61.3500   86.8500  78.4500
# 5               lfw_5590/Aaron_Tippin_0001.jpg  62.8500   85.6500  78.1500
# 6                  lfw_5590/Abba_Eban_0001.jpg  64.0500   88.0500  80.8500
# 7        lfw_5590/Abdel_Aziz_Al-Hakim_0001.jpg  67.0500   89.5500  82.6500
# 8        lfw_5590/Abdel_Nasser_Assidi_0001.jpg  62.8500   89.5500  75.1500
# 9          lfw_5590/Abdulaziz_Kamilov_0001.jpg  65.5500   88.6500  77.8500
# 10                  lfw_5590/Abdullah_0001.jpg  64.3500   89.5500  76.6500
# ...

# %%
sorted_arr = im[df['map_to_img']]

# %%
sorted_arr[0]
# Out:
# array([[  0,   0,   0, ...,   0,   0,   0],
#        [  2,   2,   2, ...,   4,   4,   4],
#        [  5,   5,   5, ...,  10,  10,  10],
#        ...,
#        [125, 134, 141, ..., 124, 123, 132],
#        [120, 131, 142, ..., 126, 132, 145],
#        [117, 126, 140, ..., 127, 140, 155]], dtype=uint8)

# %%
from sklearn.utils import shuffle
df = shuffle(df)
# Out:
# [1648,
#  3990,
#  9371,
#  7738,
#  9158,
#  3033,
#  1506,
#  338,
#  9927,
#  7960,
#  9300,
#  2220,
#  658,
#  6463,
#  7660,
#  7783,
#  688,
#  6524,
#  2242,
#  1141,
#  3004,
#  5861,
#  985,
#  2872,
#  6217,
#  1017,
#  9706,
#  3579,
#  9954,
#  6228,
#  902,
#  4706,
#  4800,
#  7752,
#  6088,
#  7859,
#  7737,
#  6992,
#  5615,
#  8248,
#  5674,
#  5677,
#  6707,
#  2647,
#  455,
#  9507,
#  2988,
#  2865,
#  3643,
#  8285,
#  2117,
#  6506,
#  1647,
#  4653,
#  6274,
#  8315,
#  4848,
#  4571,
#  4543,
#  9379,
#  1475,
#  6733,
#  2877,
#  404,
#  7441,
#  1759,
#  9561,
#  7594,
#  7459,
#  5175,
#  5322,
#  3999,
#  9190,
#  1723,
#  6433,
#  2968,
#  9458,
#  4399,
#  2672,
#  501,
#  8058,
#  7789,
#  5854,
#  5401,
#  6126,
#  9545,
#  6220,
#  4564,
#  3993,
#  731,
#  613,
#  1354,
#  4327,
#  371,
#  386,
#  2006,
#  8254,
#  1309,
#  2240,
#  6138,
#  291,
#  795,
#  1316,
#  6432,
#  8906,
#  4824,
#  1640,
#  9104,
#  7867,
#  7014,
#  3101,
#  8816,
# ...

# %%
sorted_arr=im[df['map_to_img'].tolist()]

# %%
np.save('sorted_img',sorted_arr)

# %%
df.to_csv('sorted.csv',index='False')
df1 = pd.read_csv('sorted.csv',index_col=0)
df1
# Out:
#                                       image       x1        x2       x3  \
# 1648           lfw_5590/Iva_Majoli_0001.jpg  61.6500   88.6500  74.5500
# 3990           lfw_5590/Uzi_Landau_0001.jpg  64.9500   88.9500  78.1500
# 9371                net_7876/_40_1666_1.jpg  61.8750   83.4375  81.5625
# 7738               net_7876/_-20_1193_1.jpg  59.0625   90.0000  69.3750
# 9158                net_7876/_40_1075_0.jpg  58.1250   91.8750  84.3750
# 3033        lfw_5590/Parthiv_Patel_0001.jpg  63.1500   89.8500  70.9500
# 1506       lfw_5590/Hayley_Tullett_0001.jpg  64.0500   88.3500  75.4500
# 338        lfw_5590/Beatriz_Merino_0001.jpg  62.5500   90.1500  75.7500
# 9927                net_7876/_60_4383_0.jpg  74.0625   89.0625  87.1875
# 7960               net_7876/_-20_1600_0.jpg  60.9375   92.8125  67.5000
# 9300                net_7876/_40_1469_0.jpg  67.5000   90.0000  92.8125
# 2220      lfw_5590/Kenneth_Branagh_0001.jpg  62.8500   90.4500  74.2500
# ...
